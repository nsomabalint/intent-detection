# %%
import pandas as pd
import numpy as np
import cufflinks as cf

from utils.data_utils import load_dataset_df

# %%
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = load_dataset_df()

# %%
data.head()
# Out:
#                                                 text        intent ds_name
# 0                     i am still waiting on my card?  card_arrival   train
# 1  what can i do if my card still hasn't arrived ...  card_arrival   train
# 2  i have been waiting over a week. is the card s...  card_arrival   train
# 3  can i track my card while it is in the process...  card_arrival   train
# 4  how do i know if i will get my card, or if it ...  card_arrival   train

# %%
(data.groupby('intent').count()['text']
     .sort_values(ascending=False).iplot(kind='bar',
                                         yTitle='Count',
                                         opacity=0.8,
                                         title='Intent phrase numbers',
                                         linecolor='black',
                                         xTitle='Intent'))
# Out:
# <div>                            <div id="1d77e3eb-6f02-4241-9295-9a7e2775de9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("1d77e3eb-6f02-4241-9295-9a7e2775de9d")) {                    Plotly.newPlot(                        "1d77e3eb-6f02-4241-9295-9a7e2775de9d",                        [{"marker":{"color":"rgba(255, 153, 51, 0.8)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"text","orientation":"v","text":"","x":["card_payment_fee_charged","balance_not_updated_after_cheque_or_cash_deposit","direct_debit_payment_not_recognised","wrong_amount_of_cash_received","transaction_charged_twice","cash_withdrawal_charge","transfer_fee_charged","declined_cash_withdrawal","transfer_not_received_by_recipient","balance_not_updated_after_bank_transfer","card_payment_not_recognised","request_refund","card_payment_wrong_exchange_rate","extra_charge_on_statement","wrong_exchange_rate_for_cash_withdrawal","Refund_not_showing_up","reverted_card_payment?","cash_withdrawal_not_recognised","activate_my_card","pending_card_payment","cancel_transfer","beneficiary_not_allowed","card_arrival","declined_card_payment","pending_transfer","pending_top_up","top_up_reverted","top_up_failed","pending_cash_withdrawal","card_linking","failed_transfer","declined_transfer","visa_or_mastercard","country_support","transfer_timing","getting_spare_card","card_about_to_expire","supported_cards_and_currencies","apple_pay_or_google_pay","automatic_top_up","verify_top_up","fiat_currency_support","lost_or_stolen_phone","change_pin","edit_personal_details","disposable_card_limits","why_verify_identity","exchange_charge","order_physical_card","exchange_via_app","verify_source_of_funds","top_up_by_card_charge","pin_blocked","exchange_rate","top_up_by_cash_or_cheque","transfer_into_account","card_not_working","top_up_by_bank_transfer_charge","card_delivery_estimate","age_limit","terminate_account","get_physical_card","verify_my_identity","passcode_forgotten","topping_up_by_card","unable_to_verify_identity","getting_virtual_card","receiving_money","top_up_limits","get_disposable_virtual_card","compromised_card","atm_support","lost_or_stolen_card","card_acceptance","card_swallowed","virtual_card_not_working","contactless_not_working"],"y":[227,222,222,220,218,217,213,213,212,212,211,209,207,206,205,203,202,202,201,200,198,197,195,195,190,189,188,187,183,180,179,177,175,172,172,171,170,169,168,168,167,166,164,164,163,162,162,161,160,158,157,156,156,155,155,154,153,153,153,152,151,148,147,147,147,146,142,140,139,138,132,129,126,107,105,92,90],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222 ...

# %%
(data[data.ds_name == 'train'].groupby(['intent']).count()['text']
     .sort_values(ascending=False).iplot(kind='bar',
                                         yTitle='Count',
                                         linecolor='black',
                                         opacity=0.8,
                                         title='TRAIN - Intent phrase numbers',
                                         xTitle='Intent'))
# Out:
# <div>                            <div id="8b74744f-6776-43dd-8b7a-1fa655ed6e75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("8b74744f-6776-43dd-8b7a-1fa655ed6e75")) {                    Plotly.newPlot(                        "8b74744f-6776-43dd-8b7a-1fa655ed6e75",                        [{"marker":{"color":"rgba(255, 153, 51, 0.8)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"text","orientation":"v","text":"","x":["card_payment_fee_charged","balance_not_updated_after_cheque_or_cash_deposit","direct_debit_payment_not_recognised","wrong_amount_of_cash_received","transaction_charged_twice","cash_withdrawal_charge","transfer_fee_charged","declined_cash_withdrawal","transfer_not_received_by_recipient","balance_not_updated_after_bank_transfer","card_payment_not_recognised","request_refund","card_payment_wrong_exchange_rate","extra_charge_on_statement","wrong_exchange_rate_for_cash_withdrawal","Refund_not_showing_up","reverted_card_payment?","cash_withdrawal_not_recognised","activate_my_card","pending_card_payment","cancel_transfer","beneficiary_not_allowed","card_arrival","declined_card_payment","pending_transfer","pending_top_up","top_up_reverted","top_up_failed","pending_cash_withdrawal","card_linking","failed_transfer","declined_transfer","visa_or_mastercard","country_support","transfer_timing","getting_spare_card","card_about_to_expire","supported_cards_and_currencies","apple_pay_or_google_pay","automatic_top_up","verify_top_up","fiat_currency_support","lost_or_stolen_phone","change_pin","edit_personal_details","disposable_card_limits","why_verify_identity","exchange_charge","order_physical_card","exchange_via_app","verify_source_of_funds","top_up_by_card_charge","pin_blocked","exchange_rate","top_up_by_cash_or_cheque","transfer_into_account","card_not_working","top_up_by_bank_transfer_charge","card_delivery_estimate","age_limit","terminate_account","get_physical_card","verify_my_identity","passcode_forgotten","topping_up_by_card","unable_to_verify_identity","getting_virtual_card","receiving_money","top_up_limits","get_disposable_virtual_card","compromised_card","atm_support","lost_or_stolen_card","card_acceptance","card_swallowed","virtual_card_not_working","contactless_not_working"],"y":[167,162,162,160,158,157,153,153,152,152,151,149,147,146,145,143,142,142,141,140,138,137,135,135,130,129,128,127,123,120,119,117,115,112,112,111,110,109,108,108,107,106,104,104,103,102,102,101,100,98,97,96,96,95,95,94,93,93,93,92,91,88,87,87,87,86,82,80,79,78,72,69,66,47,45,32,30],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.33333333 ...

# %%
(data[data.ds_name == 'valid'].groupby(['intent']).count()['text']
     .sort_values(ascending=False).iplot(kind='bar',
                                         yTitle='Count',
                                         opacity=0.8,
                                         title='VAL - Intent phrase numbers',
                                         xTitle='Intent'))
# Out:
# <div>                            <div id="808e125e-6ea9-4715-8896-e4b8df8514e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("808e125e-6ea9-4715-8896-e4b8df8514e6")) {                    Plotly.newPlot(                        "808e125e-6ea9-4715-8896-e4b8df8514e6",                        [{"marker":{"color":"rgba(255, 153, 51, 0.8)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"text","orientation":"v","text":"","x":["Refund_not_showing_up","pending_transfer","top_up_by_bank_transfer_charge","terminate_account","supported_cards_and_currencies","reverted_card_payment?","request_refund","receiving_money","pin_blocked","pending_top_up","get_physical_card","pending_cash_withdrawal","pending_card_payment","passcode_forgotten","order_physical_card","lost_or_stolen_phone","lost_or_stolen_card","getting_virtual_card","top_up_by_card_charge","top_up_by_cash_or_cheque","top_up_failed","top_up_limits","wrong_amount_of_cash_received","why_verify_identity","visa_or_mastercard","virtual_card_not_working","verify_top_up","verify_source_of_funds","verify_my_identity","unable_to_verify_identity","transfer_timing","transfer_not_received_by_recipient","transfer_into_account","transfer_fee_charged","transaction_charged_twice","topping_up_by_card","top_up_reverted","getting_spare_card","get_disposable_virtual_card","activate_my_card","card_about_to_expire","card_payment_not_recognised","card_payment_fee_charged","card_not_working","card_linking","card_delivery_estimate","card_arrival","card_acceptance","cancel_transfer","fiat_currency_support","beneficiary_not_allowed","balance_not_updated_after_cheque_or_cash_deposit","balance_not_updated_after_bank_transfer","automatic_top_up","atm_support","apple_pay_or_google_pay","age_limit","card_payment_wrong_exchange_rate","card_swallowed","cash_withdrawal_charge","cash_withdrawal_not_recognised","failed_transfer","extra_charge_on_statement","exchange_via_app","exchange_rate","exchange_charge","edit_personal_details","disposable_card_limits","direct_debit_payment_not_recognised","declined_transfer","declined_cash_withdrawal","declined_card_payment","country_support","contactless_not_working","compromised_card","change_pin","wrong_exchange_rate_for_cash_withdrawal"],"y":[20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20,20],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786" ...

# %%
(data[data.ds_name == 'test'].groupby(['intent']).count()['text']
     .sort_values(ascending=False).iplot(kind='bar',
                                         yTitle='Count',
                                         opacity=0.8,
                                         title='TEST - Intent phrase numbers',
                                         xTitle='Intent'))
# Out:
# <div>                            <div id="1d182d06-7ac5-425f-903b-9552ac112e4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("1d182d06-7ac5-425f-903b-9552ac112e4d")) {                    Plotly.newPlot(                        "1d182d06-7ac5-425f-903b-9552ac112e4d",                        [{"marker":{"color":"rgba(255, 153, 51, 0.8)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"text","orientation":"v","text":"","x":["Refund_not_showing_up","pending_transfer","top_up_by_bank_transfer_charge","terminate_account","supported_cards_and_currencies","reverted_card_payment?","request_refund","receiving_money","pin_blocked","pending_top_up","get_physical_card","pending_cash_withdrawal","pending_card_payment","passcode_forgotten","order_physical_card","lost_or_stolen_phone","lost_or_stolen_card","getting_virtual_card","top_up_by_card_charge","top_up_by_cash_or_cheque","top_up_failed","top_up_limits","wrong_amount_of_cash_received","why_verify_identity","visa_or_mastercard","virtual_card_not_working","verify_top_up","verify_source_of_funds","verify_my_identity","unable_to_verify_identity","transfer_timing","transfer_not_received_by_recipient","transfer_into_account","transfer_fee_charged","transaction_charged_twice","topping_up_by_card","top_up_reverted","getting_spare_card","get_disposable_virtual_card","activate_my_card","card_about_to_expire","card_payment_not_recognised","card_payment_fee_charged","card_not_working","card_linking","card_delivery_estimate","card_arrival","card_acceptance","cancel_transfer","fiat_currency_support","beneficiary_not_allowed","balance_not_updated_after_cheque_or_cash_deposit","balance_not_updated_after_bank_transfer","automatic_top_up","atm_support","apple_pay_or_google_pay","age_limit","card_payment_wrong_exchange_rate","card_swallowed","cash_withdrawal_charge","cash_withdrawal_not_recognised","failed_transfer","extra_charge_on_statement","exchange_via_app","exchange_rate","exchange_charge","edit_personal_details","disposable_card_limits","direct_debit_payment_not_recognised","declined_transfer","declined_cash_withdrawal","declined_card_payment","country_support","contactless_not_working","compromised_card","change_pin","wrong_exchange_rate_for_cash_withdrawal"],"y":[40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40,40],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786" ...

# %%
data['text'].apply(len).iplot(
    kind='hist',
    bins=50,
    xTitle='review length',
    linecolor='black',
    yTitle='count',
    title='Text len distribution')
# Out:
# <div>                            <div id="18c10da7-457a-4301-8f00-8062cce639e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("18c10da7-457a-4301-8f00-8062cce639e5")) {                    Plotly.newPlot(                        "18c10da7-457a-4301-8f00-8062cce639e5",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#000000","width":1.3}},"name":"text","nbinsx":50,"opacity":0.8,"orientation":"v","x":[30,60,58,59,54,33,44,54,44,41,35,61,48,72,53,50,68,93,53,41,30,23,21,66,36,28,47,52,46,34,27,40,43,45,41,53,35,52,46,50,53,34,59,50,43,45,46,43,30,63,42,58,82,48,48,31,23,36,29,103,58,30,69,50,53,65,43,81,44,28,46,49,82,35,46,35,50,17,55,49,30,75,36,33,30,37,45,58,40,35,63,54,29,46,36,27,60,66,44,75,59,54,39,62,56,45,37,46,20,31,58,37,40,41,29,38,31,36,63,35,42,105,50,52,34,52,68,63,45,55,44,41,55,38,22,76,69,40,59,43,47,43,103,46,41,43,53,33,41,51,40,90,54,42,98,52,24,69,55,31,36,41,34,32,71,55,25,86,89,63,86,94,44,44,48,66,43,24,68,38,35,75,37,28,26,56,60,69,56,38,41,148,28,66,54,46,32,61,26,33,45,43,123,28,49,56,53,24,84,99,123,45,36,55,85,98,52,44,33,100,55,39,34,78,54,54,37,20,33,28,40,80,57,25,46,91,40,27,38,46,29,39,41,48,40,37,32,89,40,55,51,47,55,54,67,42,33,70,34,31,79,49,56,41,44,28,35,36,44,33,39,47,48,52,36,34,24,41,39,36,56,46,34,43,42,36,41,34,41,45,25,42,36,39,35,40,34,35,45,26,32,47,42,42,34,49,35,30,29,31,42,38,45,56,37,69,58,24,40,42,42,38,50,29,28,47,42,105,52,62,33,42,40,36,47,59,32,33,53,42,65,44,38,35,25,42,35,38,39,38,91,59,61,76,117,42,48,90,42,41,85,59,53,174,115,67,61,51,31,48,79,55,75,46,47,84,68,49,42,57,57,64,47,30,110,83,43,51,79,67,72,89,62,52,102,90,31,59,73,89,51,85,71,99,58,44,90,79,71,67,33,64,68,47,132,58,65,43,70,95,42,65,75,147,139,87,49,56,135,157,69,76,66,61,43,56,97,70,58,79,64,53,87,55,41,75,59,94,89,74,107,54,51,52,65,40,101,69,50,36,61,44,58,66,56,82,99,115,56,93,71,85,57,60,69,42,47,84,53,72,76,70,30,117,64,63,65,70,89,51,41,176,78,68,122,49,97,35,42,48,49,41,36,34,53,105,66,73,70,41,54,64,49,48,97,39,45,130,35,45,39,44,90,41,25,70,51,35,34,65,136,39,117,48,63,46,38,43,120,75,28,27,28,42,65,68,56,99,36,38,36,38,55,34,32,53,44,40,51,38,56,40,46,37,78,32,26,43,43,100,121,50,51,33,56,109,39,47,36,173,111,37,123,42,90,83,147,146,68,43,55,45,84,61,55,74,54,120,55,39,26,87,55,64,195,52,29,42,138,60,47,57,87,64,34,34,67,38,73,84,57,56,41,45,115,67,67,43,83,47,60,47,97,87,153,45,23,60,38,50,69,41,38,51,41,66,177,39,37,47,133,48,33,334,49,279,43,100,58,88,40,63,105,221,104,83,146,52,237,34,46,336,48,83,42,37,42,85,33,138,45,44,61,155,61,64,50,27,52,198,192,66,55,99,238,70,42,56,34,216,313,34,36,244,48,42,63,134,49,60,52,55,74,39,28,84,51,35,53,41,190,121,43,45,29,40,46,60,73,35,135,65,133,43,62,67,79,228,37,47,58,117,30,92,53,39,59,59,51,117,63,31,134,197,62,50,67,295,139,56,72,116,87,54,282,46,50,32,34,48,57,27,37,31,26,61,23,58,29,23,34,60,43,29,58,42,34,40,61,37,48,63,47,50,36,48,28,82,27,30,50,73,52,45,56,58,31,31,30,36,50,61,36,43,29,64,49,44,65,85,29,58,35,52,44,30,49,69,53,55,43,44,38,80,34,50,50,30,60,49,59,48,31,39,41,43,80,37,53,40,35,21,98,63,35,61,42,72,62,57,58,40,79,34,35,32,48,53,76,36,62,58,29,31,33,26,40,37,40,43,66,20,39,26,27,48,87,31,41,28,44,40,36,37,49,31,61,45,36,44,38,26,31,41,55,54,46,41,36,56,69,51,43,32,35,48,35,43,20,39,46,43,29,41,35,25,63,24,27,29,68,34,23,22,33,44,23,41,32,40,57,50,26,38,38,36,45,60,28,44,43,26,51,37,96,42,42,34,38,44,59,59,44,27,36,60,43,55,36,31,82,72,37,67,35,37,62,30,28,66,40,41,35,82,27,46,28,39,37,66,60,30,69,51,71,40,30,48,32,45,33,41,31,33,34,43,80,100,46,55,34,35,51,30,21,47,34,68,49,42,36,59,37,52,60,67,25,84,26,32,61,30,39,41,63,53,32,28,33,38,45,37,44,33,44,44,25,39,41,33,39,27,61,43,25,60,44,31,45,40,60,61,70,78,32,38,78,36,65,29,36,70,39,46,38,73,88,27,39,29,49,38,45,38,72,33,36,41,21,23,39,42,43,24,25,33,138,27,44,44,44,60,55,39,46,43,62,44,37,29,38,36,25,27,62,65,41,42,33,35,32,79,40,36,34,84,29,38,39,29,44,50,196,47,67,27,92,62,51,33,45,120,46,57,42,97,17,139,24 ...

# %%
data['text_len'] = data.text.apply(len)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 (data[data.ds_name == 'train'].groupby('intent').text_len.agg([np.mean]).rename({"mean": "train_len_mean"}).join(data[data.ds_name == 'test'].groupby('intent').text_len.agg([np.mean]).rename({"mean": "test_len_mean"})))
#
# File ~/Library/Caches/pypoetry/virtualenvs/intent-detection-sBxw7ymE-py3.8/lib/python3.8/site-packages/pandas/core/frame.py:9254, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort)
#    9100 def join(
#    9101     self,
#    9102     other: DataFrame | Series,
#    (...)
#    9107     sort: bool = False,
#    9108 ) -> DataFrame:
#    9109     """
#    9110     Join columns of another DataFrame.
#    9111
#    (...)
#    9252     5  K1  A5   B1
#    9253     """
# -> 9254     return self._join_compat(
#    9255         other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9256     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/intent-detection-sBxw7ymE-py3.8/lib/python3.8/site-packages/pandas/core/frame.py:9285, in DataFrame._join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9276     if how == "cross":
#    9277         return merge(
#    9278             self,
#    9279             other,
#    (...)
#    9283             sort=sort,
#    9284         )
# -> 9285     return merge(
#    9286         self,
#    9287         other,
#    9288         left_on=on,
#    9289         how=how,
#    9290         left_index=on is None,
#    9291         right_index=True,
#    9292         suffixes=(lsuffix, rsuffix),
#    9293         sort=sort,
#    9294     )
#    9295 else:
#    9296     if on is not None:
#
# File ~/Library/Caches/pypoetry/virtualenvs/intent-detection-sBxw7ymE-py3.8/lib/python3.8/site-packages/pandas/core/reshape/merge.py:122, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
#     107     op = _MergeOperation(
#     108         left,
#     109         right,
#    (...)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#
# File ~/Library/Caches/pypoetry/virtualenvs/intent-detection-sBxw7ymE-py3.8/lib/python3.8/site-packages/pandas/core/reshape/merge.py:718, in _MergeOperation.get_result(self)
#     714     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     716 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 718 llabels, rlabels = _items_overlap_with_suffix(
#     719     self.left._info_axis, self.right._info_axis, self.suffixes
#     720 )
#     722 lindexers = {1: left_indexer} if left_indexer is not None else {}
#     723 rindexers = {1: right_indexer} if right_indexer is not None else {}
#
# File ~/Library/Caches/pypoetry/virtualenvs/intent-detection-sBxw7ymE-py3.8/lib/python3.8/site-packages/pandas/core/reshape/merge.py:2313, in _items_overlap_with_suffix(left, right, suffixes)
#    2310 lsuffix, rsuffix = suffixes
#    2312 if not lsuffix and not rsuffix:
# -> 2313     raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2315 def renamer(x, suffix):
#    2316     """
#    2317     Rename the left and right indices.
#    2318
#    (...)
#    2329     x : renamed column name
#    2330     """
#
# ValueError: columns overlap but no suffix specified: Index(['mean'], dtype='object')
